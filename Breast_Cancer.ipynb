# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
input_file = r'/content/data.csv'
breast=pd.read_csv(input_file)
breast.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
breast['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %% [markdown]
# B - not cancer
# M - cancer

# %%
breast['diagnosis'] = breast['diagnosis'].map({'M': 1, 'B': 0})  # Map 'M' to 1 and 'B' to 0

# Now calculate the correlation
breast.corr()
# Out:
#                                id  diagnosis  radius_mean  texture_mean  \
# id                       1.000000   0.039769     0.074626      0.099770
# diagnosis                0.039769   1.000000     0.730029      0.415185
# radius_mean              0.074626   0.730029     1.000000      0.323782
# texture_mean             0.099770   0.415185     0.323782      1.000000
# perimeter_mean           0.073159   0.742636     0.997855      0.329533
# area_mean                0.096893   0.708984     0.987357      0.321086
# smoothness_mean         -0.012968   0.358560     0.170581     -0.023389
# compactness_mean         0.000096   0.596534     0.506124      0.236702
# concavity_mean           0.050080   0.696360     0.676764      0.302418
# concave points_mean      0.044158   0.776614     0.822529      0.293464
# symmetry_mean           -0.022114   0.330499     0.147741      0.071401
# fractal_dimension_mean  -0.052511  -0.012838    -0.311631     -0.076437
# ...

# %%
breast.drop('Unnamed: 32', axis=1, inplace=True)

# %% [markdown]
# **ENCODING THE TARGET VARIABLE**

# %%
from sklearn.preprocessing import LabelEncoder

breast['diagnosis'].map({"M":1, "B":0})
breast.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# **SPLITTING DATA SET INTO TRAINING AND TESTING**

# %%
x = breast.drop('diagnosis',axis=1)
y = breast['diagnosis']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# **FEATURE SCALLING**

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
sc.fit(X_train)
# Out:
# StandardScaler()

# %%
x_train = sc.transform(X_train)
x_test = sc.transform(X_test)

# %%
# Import Logistic Regression
from sklearn.linear_model import LogisticRegression

# Initialize the Logistic Regression model
model = LogisticRegression()

# Train the model (example: using x_train and y_train)
model.fit(x_train, y_train)

# Make predictions
predictions = model.predict(x_test)

# Evaluate the model
accuracy = model.score(x_test, y_test)*100
print(f"Model Accuracy: {accuracy:}")
# Out:
# Model Accuracy: 97.36842105263158

# %% [markdown]
# # **PREDICTION SYSTEM**

# %%
import numpy as np

# Assuming 'breast' is your original DataFrame
feature_names = breast.drop('diagnosis', axis=1).columns  # Get feature names

# Simulating user input as a dictionary
input_text = ([-0.17478099, -0.25698012,  1.42326216, -0.32031902, -0.32851959,
       -0.56328674, -0.98390686, -0.77069479, -0.72596174, -0.69922504,
       -0.96042428, -0.68451875,  0.27222162, -0.74640146, -0.47666829,
       -0.39989692, -0.94442957, -0.55196315, -0.86571951, -0.87021209,
       -0.71566322, -0.39224142,  1.43507375, -0.47432767, -0.43045164,
       -0.11415698, -0.94573859, -0.64825719, -0.82955846, -0.73083204,
       -0.89676905])

# Create a DataFrame from the input dictionary
input_df = pd.DataFrame([input_text])

# Ensure `model` is already trained before prediction
# Applying the same scaling used during training:
input_data_scaled = sc.transform(input_df)

prediction = model.predict(input_data_scaled)

# Print the prediction
print(prediction)


if prediction[0] == 0:
    print('The breast cancer is Malignant (Not there - hurray)')
else:
    print('The breast cancer is Benign (Cancer detected)')
# Out:
# [0]
# The breast cancer is Malignant (Not there - hurray)
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import pickle

# Save the model to a file
with open('model.pkl', 'wb') as file:
    pickle.dump(model, file)

print("Model saved successfully!")
# Out:
# Model saved successfully!
